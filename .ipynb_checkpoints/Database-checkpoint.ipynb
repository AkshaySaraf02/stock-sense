# %%
from pandas_datareader import data as stocksAPI
import yfinance 
from collections import OrderedDict
import warnings
warnings.filterwarnings("ignore")

# %%
from Firebase.firebase_config import db

# %%
def add_stocks_data(ticker):
    try:
        df = stocksAPI.DataReader(name=ticker[1].upper(), data_source = "iex",
                            start="2020-01-01", end="2023-07-16", api_key="sk_08dcd11ddf014b7cb57250522079d96e")
        data = {"prices": df[["open", "close", "high", "low", "volume"]].to_dict(orient="index")}
        data["ticker"] = ticker[1].upper()
        data["name"] = ticker[0]
        update_time, doc_ref = db.collection("stock_prices_data").add(data)
        print(f"Document added with id: {doc_ref.id}")
        
    except Exception as e:
        print(e)

# %%
# ["Apple", "AAPL"], ["Microsoft", "MSFT"], ["Amazon.com", "AMZN"],
# ["Facebook", "FB"], ["Tesla", "TSLA"], ["Google", "GOOGL"]

# %%
top_100_stocks = [["Berkshire Hathaway", "BRK-A"], ["Johnson & Johnson", "JNJ"], 
["JPMorgan Chase", "JPM"], ["Visa", "V"], ["Procter & Gamble", "PG"], ["NVIDIA", "NVDA"], ["UnitedHealth Group", "UNH"],
["Mastercard", "MA"], ["Home Depot", "HD"], ["Intel", "INTC"], ["PayPal", "PYPL"], ["Walt Disney", "DIS"],
["Salesforce", "CRM"], ["Bank of America", "BAC"], ["Exxon Mobil", "XOM"], ["Verizon Communications", "VZ"], 
["Netflix", "NFLX"], ["AT&T", "T"], ["Coca-Cola", "KO"], ["Pfizer", "PFE"], ["Comcast", "CMCSA"], ["McDonald's", "MCD"],
["Cisco Systems", "CSCO"], ["Abbott Laboratories", "ABT"], ["Walmart", "WMT"], ["Accenture", "ACN"], ["Merck & Co.", "MRK"],
["Wells Fargo", "WFC"], ["Nike", "NKE"], ["Chevron", "CVX"], ["PepsiCo", "PEP"], ["Pinduoduo", "PDD"], ["Qualcomm", "QCOM"],
["Thermo Fisher Scientific", "TMO"], ["Broadcom", "AVGO"], ["Costco Wholesale", "COST"], ["Boeing", "BA"], 
["Taiwan Semiconductor", "TSM"], ["Walgreens Boots Alliance", "WBA"], ["Honeywell International", "HON"], ["Linde", "LIN"],
["Oracle", "ORCL"], ["Union Pacific", "UNP"], ["Advanced Micro Devices", "AMD"], ["Alibaba", "BABA"], ["Danaher", "DHR"],
["Lockheed Martin", "LMT"], ["Texas Instruments", "TXN"], ["Airbnb", "ABNB"], ["Citigroup", "C"], ["Caterpillar", "CAT"],
["NextEra Energy", "NEE"], ["IBM", "IBM"], ["Amgen", "AMGN"], ["Philip Morris", "PM"], ["General Electric", "GE"], 
["Altria Group", "MO"], ["SAP SE", "SAP"], ["Medtronic", "MDT"], ["Eli Lilly and Company", "LLY"], 
["Bristol-Myers Squibb", "BMY"], ["Shopify", "SHOP"], ["Pinduoduo", "PDD"], ["Danaher", "DHR"], ["Chevron", "CVX"],
["United Parcel Service", "UPS"], ["HDFC Bank", "HDB"], ["3M", "MMM"], ["CSX", "CSX"], ["American Tower", "AMT"],
["Wells Fargo", "WFC"], ["AbbVie", "ABBV"], ["Vertex Pharmaceuticals", "VRTX"], ["British American Tobacco", "BTI"],
["American Express", "AXP"], ["AstraZeneca", "AZN"], ["Starbucks", "SBUX"], ["Pfizer", "PFE"], ["Lam Research", "LRCX"],
["BHP Group", "BHP"], ["Bristol-Myers Squibb", "BMY"], ["Sanofi", "SNY"], ["Gilead Sciences", "GILD"], ["T-Mobile", "TMUS"], 
["Target", "TGT"], ["Adobe", "ADBE"], ["Comcast", "CMCSA"], ["Bank of Montreal", "BMO"], ["Lowe's", "LOW"]]

# %%
# for stock in top_100_stocks:
#     add_stocks_data(stock)
# Out:
# Document added with id: sY2ztAe1PH8yQrb1qie3
# Document added with id: 5GCD8NTPjLS56PJ3SoBn
# Document added with id: Ml7tHp5yQxJ9FdR6IHKh
# Document added with id: BceRVZNiKeBwtwvTyPPx
# Document added with id: hBwMC0ySeW9uaajFErSb
# Document added with id: h3xl3fS7rLRQO8nKuJEo
# Unable to read URL: https://cloud.iexapis.com/stable/stock/market/batch?symbols=BRK-A&types=chart&range=5y&token=sk_08dcd11ddf014b7cb57250522079d96e
# Document added with id: CwSL8H9gOCwab8yraBH0
# Document added with id: fVX75OtsY3LzE2vFmChr
# Document added with id: fWBSmT9w57YZdcY50Ch7
# Document added with id: z6P5lEn4becmbgVKRBHi
# Document added with id: F47vnB18a0gdOLWOoJoF
# Document added with id: SyZrcbMU2bgQMJWpxhU3
# Document added with id: Bs466JegusJ6mDwOqIO1
# Document added with id: whWGgnlRfU7Blmh8uNM5
# Document added with id: NMOTwIGXTHvpkox2sb6Q
# Document added with id: QOS40xTozOFCgMXae9pm
# Document added with id: rj50j57beYTnjPMgJntd
# Document added with id: DqYtnbmLREBbBHQ5caFR
# ...

# %%
def update_database(ticker):
    try:
        doc_ref = db.collection("stock_prices_data").where("ticker", "==", ticker).get()[0]
        document = doc_ref.to_dict()
        last_date = list(document["prices"].keys())[-1]
        curr_date = datetime.today().strftime('%Y-%m-%d')
        old_data = document["prices"]
    
        last_date = datetime.strptime(last_date, '%Y-%m-%d') + timedelta(days=1)
        new_date_str = last_date.strftime('%Y-%m-%d')
        
        df = stocksAPI.DataReader(name=ticker.upper(), data_source = "iex",
                            start=last_date, end=curr_date, api_key="sk_08dcd11ddf014b7cb57250522079d96e")
        
        data = {"prices": df[["open", "close", "high", "low", "volume"]].to_dict(orient="index")}
        data = OrderedDict(list(old_data.items()) + list(data.items()))
        doc_ref.reference.update({"prices": data})
        name = document["name"]
        print(f"Updated {name}'s data successfully!")
        
    except Exception as e:
        print(e)
        pass

# %%
for stock in top_100_stocks:
    update_database(stock[1])
# Out:
# list index out of range
# Updated Johnson & Johnson's data successfully!
# Updated JPMorgan Chase's data successfully!
# Updated Visa's data successfully!
# Updated Procter & Gamble's data successfully!
# Updated NVIDIA's data successfully!
# Updated UnitedHealth Group's data successfully!
# Updated Mastercard's data successfully!
# Updated Home Depot's data successfully!
# Updated Intel's data successfully!
# Updated PayPal's data successfully!
# Updated Walt Disney's data successfully!
# Updated Salesforce's data successfully!
# Updated Bank of America's data successfully!
# Updated Exxon Mobil's data successfully!
# Updated Verizon Communications's data successfully!
# Updated Netflix's data successfully!
# Updated AT&T's data successfully!
# Updated Coca-Cola's data successfully!
# Updated Pfizer's data successfully!
# Updated Comcast's data successfully!
# Updated McDonald's's data successfully!
# Updated Cisco Systems's data successfully!
# ...

# %%
doc_ref = db.collection("stock_prices_data").where("ticker", "==", "WFC").get()[0]
document = doc_ref.to_dict()

# %%
pd.DataFrame(document["prices"])
# Out:
#              2020-02-21    2022-09-22    2022-09-06   2020-03-27  \
# volume      21729106.00  1.549900e+07  1.470872e+07  38942842.00
# close             47.70  4.152000e+01  4.288000e+01        30.28
# high              47.85  4.250500e+01  4.388000e+01        31.29
# open              47.48  4.249000e+01  4.371000e+01        30.02
# low               47.10  4.144000e+01  4.235500e+01        29.08
# ...                 ...           ...           ...          ...
# 2023-05-17          NaN           NaN           NaN          NaN
# 2023-03-17          NaN           NaN           NaN          NaN
# 2023-07-14          NaN           NaN           NaN          NaN
# 2022-12-28          NaN           NaN           NaN          NaN
# 2023-02-17          NaN           NaN           NaN          NaN
#
#               2023-04-10   2021-01-26   2020-01-06    2023-02-15  \
# volume      2.700582e+07  28026455.00  13200655.00  1.285671e+07
# ...
